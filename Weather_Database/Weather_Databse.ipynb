# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | narsaq
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | mwinilunga
# Processing Record 6 of Set 1 | avinurme
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | san fernando
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | butaritari
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | sampit
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | lasa
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | hambantota
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | kargasok
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | jertih
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | ahipara
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | portland
# Processing Record 31 of Set 1 | muisne
# Processing Record 32 of Set 1 | opuwo
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | houma
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | bismarck
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | coos bay
# Processing Record 40 of Set 1 | kampene
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | ostrovnoy
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | bubaque
# Processing Record 45 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 1 | saint-paul
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | vila velha
# Processing Record 50 of Set 1 | boulsa
# Processing Record 1 of Set 2 | rio gallegos
# Processing Record 2 of Set 2 | a coruna
# Processing Record 3 of Set 2 | neiafu
# Processing Record 4 of Set 2 | fayaoue
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 2 | road town
# Processing Record 8 of Set 2 | itarema
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | rudnyy
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | khatanga
# Processing Record 13 of Set 2 | kumluca
# Processing Record 14 of Set 2 | preston
# Processing Record 15 of Set 2 | sumbe
# Processing Record 16 of Set 2 | sola
# Processing Record 17 of Set 2 | baykit
# Processing Record 18 of Set 2 | shimoda
# Processing Record 19 of Set 2 | oxford
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | bundaberg
# Processing Record 23 of Set 2 | hithadhoo
# Processing Record 24 of Set 2 | tambopata
# Processing Record 25 of Set 2 | gravdal
# Processing Record 26 of Set 2 | columbus
# Processing Record 27 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 28 of Set 2 | presidencia roque saenz pena
# Processing Record 29 of Set 2 | hofn
# Processing Record 30 of Set 2 | lavrentiya
# Processing Record 31 of Set 2 | husavik
# Processing Record 32 of Set 2 | jiquilpan
# Processing Record 33 of Set 2 | puerto madryn
# Processing Record 34 of Set 2 | kavieng
# Processing Record 35 of Set 2 | norman wells
# Processing Record 36 of Set 2 | half moon bay
# Processing Record 37 of Set 2 | burdur
# Processing Record 38 of Set 2 | san patricio
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | biak
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | dingle
# Processing Record 43 of Set 2 | casper
# Processing Record 44 of Set 2 | touros
# Processing Record 45 of Set 2 | mehamn
# Processing Record 46 of Set 2 | ilulissat
# Processing Record 47 of Set 2 | harper
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | chancay
# Processing Record 50 of Set 2 | ucluelet
# Processing Record 1 of Set 3 | robertsport
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | tubuala
# Processing Record 5 of Set 3 | russell
# Processing Record 6 of Set 3 | muros
# Processing Record 7 of Set 3 | albany
# Processing Record 8 of Set 3 | teknaf
# Processing Record 9 of Set 3 | namatanai
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | padang
# Processing Record 12 of Set 3 | port elizabeth
# Processing Record 13 of Set 3 | marathon
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | kultuk
# Processing Record 16 of Set 3 | airai
# Processing Record 17 of Set 3 | richards bay
# Processing Record 18 of Set 3 | saint-pierre
# Processing Record 19 of Set 3 | constitucion
# Processing Record 20 of Set 3 | viedma
# Processing Record 21 of Set 3 | san cristobal
# Processing Record 22 of Set 3 | yulara
# Processing Record 23 of Set 3 | puerto palomas
# Processing Record 24 of Set 3 | salinopolis
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | santona
# Processing Record 27 of Set 3 | madimba
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | port hardy
# Processing Record 32 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 3 | kapaa
# Processing Record 34 of Set 3 | severo-kurilsk
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | sarangani
# Processing Record 37 of Set 3 | aksaray
# Processing Record 38 of Set 3 | ballina
# Processing Record 39 of Set 3 | berbera
# Processing Record 40 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 3 | birjand
# Processing Record 42 of Set 3 | georgetown
# Processing Record 43 of Set 3 | vila franca do campo
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | dzerzhinskoye
# Processing Record 46 of Set 3 | lianzhou
# Processing Record 47 of Set 3 | tura
# Processing Record 48 of Set 3 | grants
# Processing Record 49 of Set 3 | guiglo
# Processing Record 50 of Set 3 | jalu
# Processing Record 1 of Set 4 | pizarro
# Processing Record 2 of Set 4 | finschhafen
# Processing Record 3 of Set 4 | colombo
# Processing Record 4 of Set 4 | tuktoyaktuk
# Processing Record 5 of Set 4 | aykhal
# Processing Record 6 of Set 4 | huarmey
# Processing Record 7 of Set 4 | lompoc
# Processing Record 8 of Set 4 | marawi
# Processing Record 9 of Set 4 | boende
# Processing Record 10 of Set 4 | roald
# Processing Record 11 of Set 4 | saskylakh
# Processing Record 12 of Set 4 | chara
# Processing Record 13 of Set 4 | bahia honda
# Processing Record 14 of Set 4 | svetlyy
# Processing Record 15 of Set 4 | kahului
# Processing Record 16 of Set 4 | urusha
# Processing Record 17 of Set 4 | maturin
# Processing Record 18 of Set 4 | vung tau
# Processing Record 19 of Set 4 | kaitangata
# Processing Record 20 of Set 4 | usinsk
# Processing Record 21 of Set 4 | clyde river
# Processing Record 22 of Set 4 | vaini
# Processing Record 23 of Set 4 | eenhana
# Processing Record 24 of Set 4 | udachnyy
# Processing Record 25 of Set 4 | cabo san lucas
# Processing Record 26 of Set 4 | leningradskiy
# Processing Record 27 of Set 4 | oussouye
# Processing Record 28 of Set 4 | puerto escondido
# Processing Record 29 of Set 4 | samarai
# Processing Record 30 of Set 4 | aklavik
# Processing Record 31 of Set 4 | katsuura
# Processing Record 32 of Set 4 | balkhash
# Processing Record 33 of Set 4 | chapais
# Processing Record 34 of Set 4 | pokhara
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | salvador
# Processing Record 37 of Set 4 | bathsheba
# Processing Record 38 of Set 4 | isangel
# Processing Record 39 of Set 4 | east london
# Processing Record 40 of Set 4 | mount gambier
# Processing Record 41 of Set 4 | shingu
# Processing Record 42 of Set 4 | nhulunbuy
# Processing Record 43 of Set 4 | coquimbo
# Processing Record 44 of Set 4 | sarh
# Processing Record 45 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 4 | zhenhai
# Processing Record 47 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 48 of Set 4 | kuching
# Processing Record 49 of Set 4 | hasaki
# Processing Record 50 of Set 4 | butterworth
# Processing Record 1 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 2 of Set 5 | general roca
# Processing Record 3 of Set 5 | guerrero negro
# Processing Record 4 of Set 5 | bredasdorp
# Processing Record 5 of Set 5 | esmeraldas
# Processing Record 6 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 5 | lemont
# Processing Record 8 of Set 5 | lahij
# Processing Record 9 of Set 5 | acapulco
# Processing Record 10 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 5 | maningrida
# Processing Record 12 of Set 5 | maniitsoq
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | lam luk ka
# Processing Record 15 of Set 5 | maraba
# Processing Record 16 of Set 5 | victoria
# Processing Record 17 of Set 5 | quelimane
# Processing Record 18 of Set 5 | kemlya
# Processing Record 19 of Set 5 | qaanaaq
# Processing Record 20 of Set 5 | dolinsk
# Processing Record 21 of Set 5 | flinders
# Processing Record 22 of Set 5 | saint anthony
# Processing Record 23 of Set 5 | ribeira grande
# Processing Record 24 of Set 5 | port blair
# Processing Record 25 of Set 5 | matara
# Processing Record 26 of Set 5 | nouadhibou
# Processing Record 27 of Set 5 | koslan
# Processing Record 28 of Set 5 | sabya
# Processing Record 29 of Set 5 | kingsport
# Processing Record 30 of Set 5 | iqaluit
# Processing Record 31 of Set 5 | mongoumba
# Processing Record 32 of Set 5 | banda aceh
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | isiro
# Processing Record 35 of Set 5 | anadyr
# Processing Record 36 of Set 5 | te anau
# Processing Record 37 of Set 5 | hervey bay
# Processing Record 38 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 5 | lagoa
# Processing Record 40 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 5 | baie-comeau
# Processing Record 42 of Set 5 | barrow
# Processing Record 43 of Set 5 | karamken
# City not found. Skipping...
# Processing Record 44 of Set 5 | iskateley
# Processing Record 45 of Set 5 | tasiilaq
# Processing Record 46 of Set 5 | kaka
# Processing Record 47 of Set 5 | beeville
# Processing Record 48 of Set 5 | alexandria
# Processing Record 49 of Set 5 | baruun-urt
# Processing Record 50 of Set 5 | nova borova
# Processing Record 1 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 6 | onega
# Processing Record 3 of Set 6 | lamar
# Processing Record 4 of Set 6 | vardo
# Processing Record 5 of Set 6 | gladstone
# Processing Record 6 of Set 6 | gloggnitz
# Processing Record 7 of Set 6 | cayenne
# Processing Record 8 of Set 6 | asau
# Processing Record 9 of Set 6 | omsukchan
# Processing Record 10 of Set 6 | kieta
# Processing Record 11 of Set 6 | nanortalik
# Processing Record 12 of Set 6 | dabakala
# Processing Record 13 of Set 6 | garissa
# Processing Record 14 of Set 6 | college
# Processing Record 15 of Set 6 | odweyne
# Processing Record 16 of Set 6 | mana
# Processing Record 17 of Set 6 | rafaela
# Processing Record 18 of Set 6 | luderitz
# Processing Record 19 of Set 6 | gondanglegi
# Processing Record 20 of Set 6 | the pas
# Processing Record 21 of Set 6 | bambui
# Processing Record 22 of Set 6 | faro
# Processing Record 23 of Set 6 | ixtapa
# Processing Record 24 of Set 6 | mahon
# Processing Record 25 of Set 6 | tutoia
# Processing Record 26 of Set 6 | awjilah
# Processing Record 27 of Set 6 | port macquarie
# Processing Record 28 of Set 6 | xining
# Processing Record 29 of Set 6 | daxian
# City not found. Skipping...
# Processing Record 30 of Set 6 | ewa beach
# Processing Record 31 of Set 6 | portugalete
# Processing Record 32 of Set 6 | henties bay
# Processing Record 33 of Set 6 | merauke
# Processing Record 34 of Set 6 | lebu
# Processing Record 35 of Set 6 | svobodnyy
# Processing Record 36 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 6 | izhevskoye
# Processing Record 38 of Set 6 | bengkulu
# Processing Record 39 of Set 6 | ambilobe
# Processing Record 40 of Set 6 | evensk
# Processing Record 41 of Set 6 | hay river
# Processing Record 42 of Set 6 | jaque
# Processing Record 43 of Set 6 | geraldton
# Processing Record 44 of Set 6 | krasnoselkup
# Processing Record 45 of Set 6 | nurota
# Processing Record 46 of Set 6 | oparino
# Processing Record 47 of Set 6 | lorengau
# Processing Record 48 of Set 6 | mandalgovi
# Processing Record 49 of Set 6 | loikaw
# Processing Record 50 of Set 6 | suhbaatar
# Processing Record 1 of Set 7 | bereda
# Processing Record 2 of Set 7 | botwood
# Processing Record 3 of Set 7 | savannah bight
# Processing Record 4 of Set 7 | krasnousolskiy
# City not found. Skipping...
# Processing Record 5 of Set 7 | talnakh
# Processing Record 6 of Set 7 | luganville
# Processing Record 7 of Set 7 | broome
# Processing Record 8 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 7 | terney
# Processing Record 10 of Set 7 | dicabisagan
# Processing Record 11 of Set 7 | paracuru
# Processing Record 12 of Set 7 | coahuayana
# Processing Record 13 of Set 7 | tanete
# Processing Record 14 of Set 7 | klaksvik
# Processing Record 15 of Set 7 | tommot
# Processing Record 16 of Set 7 | kandrian
# Processing Record 17 of Set 7 | taungdwingyi
# Processing Record 18 of Set 7 | seminole
# Processing Record 19 of Set 7 | kruisfontein
# Processing Record 20 of Set 7 | mogadishu
# Processing Record 21 of Set 7 | pokrovsk
# Processing Record 22 of Set 7 | pamanukan
# Processing Record 23 of Set 7 | mitrofanovka
# Processing Record 24 of Set 7 | marsh harbour
# Processing Record 25 of Set 7 | nago
# Processing Record 26 of Set 7 | qaracala
# Processing Record 27 of Set 7 | takoradi
# Processing Record 28 of Set 7 | inhambane
# Processing Record 29 of Set 7 | qarayeri
# Processing Record 30 of Set 7 | waipawa
# Processing Record 31 of Set 7 | lubao
# Processing Record 32 of Set 7 | pathein
# Processing Record 33 of Set 7 | thessalon
# Processing Record 34 of Set 7 | port said
# Processing Record 35 of Set 7 | vao
# Processing Record 36 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 7 | pangnirtung
# Processing Record 38 of Set 7 | marzuq
# Processing Record 39 of Set 7 | suez
# Processing Record 40 of Set 7 | saint george
# Processing Record 41 of Set 7 | ayoquezco
# City not found. Skipping...
# Processing Record 42 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 7 | mulki
# Processing Record 44 of Set 7 | itanhandu
# Processing Record 45 of Set 7 | luwingu
# Processing Record 46 of Set 7 | rayachoti
# Processing Record 47 of Set 7 | saint-prosper
# Processing Record 48 of Set 7 | saint-joseph
# Processing Record 49 of Set 7 | chabahar
# Processing Record 50 of Set 7 | burnie
# Processing Record 1 of Set 8 | belem de sao francisco
# Processing Record 2 of Set 8 | cap malheureux
# Processing Record 3 of Set 8 | esperance
# Processing Record 4 of Set 8 | ingraj bazar
# Processing Record 5 of Set 8 | oktyabrskoye
# Processing Record 6 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 8 | sebrovo
# Processing Record 8 of Set 8 | ayr
# Processing Record 9 of Set 8 | belmonte
# Processing Record 10 of Set 8 | huitzuco
# City not found. Skipping...
# Processing Record 11 of Set 8 | baijiantan
# Processing Record 12 of Set 8 | jiwani
# Processing Record 13 of Set 8 | pacific grove
# Processing Record 14 of Set 8 | malatya
# Processing Record 15 of Set 8 | natal
# Processing Record 16 of Set 8 | paamiut
# Processing Record 17 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 8 | hualmay
# Processing Record 19 of Set 8 | kleck
# City not found. Skipping...
# Processing Record 20 of Set 8 | gorom-gorom
# Processing Record 21 of Set 8 | nouakchott
# Processing Record 22 of Set 8 | sao desiderio
# Processing Record 23 of Set 8 | belyy yar
# Processing Record 24 of Set 8 | tanda
# Processing Record 25 of Set 8 | pevek
# Processing Record 26 of Set 8 | vysokogornyy
# Processing Record 27 of Set 8 | acuna
# City not found. Skipping...
# Processing Record 28 of Set 8 | vostok
# Processing Record 29 of Set 8 | kinablangan
# Processing Record 30 of Set 8 | los llanos de aridane
# Processing Record 31 of Set 8 | diamantino
# Processing Record 32 of Set 8 | pangkalanbuun
# Processing Record 33 of Set 8 | olafsvik
# Processing Record 34 of Set 8 | nome
# Processing Record 35 of Set 8 | winnemucca
# Processing Record 36 of Set 8 | ambulu
# Processing Record 37 of Set 8 | beringovskiy
# Processing Record 38 of Set 8 | kontagora
# Processing Record 39 of Set 8 | changli
# Processing Record 40 of Set 8 | quang ngai
# Processing Record 41 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 8 | praia
# Processing Record 43 of Set 8 | bonavista
# Processing Record 44 of Set 8 | pirmasens
# Processing Record 45 of Set 8 | jimo
# Processing Record 46 of Set 8 | goderich
# Processing Record 47 of Set 8 | kilis
# Processing Record 48 of Set 8 | monastyrshchina
# Processing Record 49 of Set 8 | launceston
# Processing Record 50 of Set 8 | santa marta
# Processing Record 1 of Set 9 | laguna
# Processing Record 2 of Set 9 | gudari
# Processing Record 3 of Set 9 | kimberley
# Processing Record 4 of Set 9 | itainopolis
# Processing Record 5 of Set 9 | bonthe
# Processing Record 6 of Set 9 | grindavik
# Processing Record 7 of Set 9 | staryy nadym
# Processing Record 8 of Set 9 | sioux lookout
# Processing Record 9 of Set 9 | halifax
# Processing Record 10 of Set 9 | portree
# Processing Record 11 of Set 9 | cap-aux-meules
# Processing Record 12 of Set 9 | isilkul
# Processing Record 13 of Set 9 | lubango
# Processing Record 14 of Set 9 | ningxiang
# Processing Record 15 of Set 9 | ambanja
# Processing Record 16 of Set 9 | karpathos
# Processing Record 17 of Set 9 | dubbo
# Processing Record 18 of Set 9 | valparaiso
# Processing Record 19 of Set 9 | charapan
# Processing Record 20 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 9 | ponta delgada
# Processing Record 22 of Set 9 | kologriv
# Processing Record 23 of Set 9 | suaita
# Processing Record 24 of Set 9 | labuhan
# Processing Record 25 of Set 9 | garden city
# Processing Record 26 of Set 9 | boshnyakovo
# Processing Record 27 of Set 9 | byron bay
# Processing Record 28 of Set 9 | tukrah
# Processing Record 29 of Set 9 | safaga
# Processing Record 30 of Set 9 | sechura
# Processing Record 31 of Set 9 | oga
# Processing Record 32 of Set 9 | souris
# Processing Record 33 of Set 9 | meulaboh
# Processing Record 34 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 9 | xai-xai
# Processing Record 36 of Set 9 | dunedin
# Processing Record 37 of Set 9 | cochabamba
# Processing Record 38 of Set 9 | haftoni
# Processing Record 39 of Set 9 | thunder bay
# Processing Record 40 of Set 9 | seydi
# Processing Record 41 of Set 9 | rosario do sul
# Processing Record 42 of Set 9 | cartagena del chaira
# Processing Record 43 of Set 9 | montrose
# Processing Record 44 of Set 9 | torbay
# Processing Record 45 of Set 9 | sur
# Processing Record 46 of Set 9 | nautla
# Processing Record 47 of Set 9 | vanimo
# Processing Record 48 of Set 9 | kovdor
# Processing Record 49 of Set 9 | tanshui
# City not found. Skipping...
# Processing Record 50 of Set 9 | almaznyy
# Processing Record 1 of Set 10 | groton
# Processing Record 2 of Set 10 | vanino
# Processing Record 3 of Set 10 | codrington
# Processing Record 4 of Set 10 | oranjemund
# Processing Record 5 of Set 10 | ambatondrazaka
# Processing Record 6 of Set 10 | phulabani
# Processing Record 7 of Set 10 | sitka
# Processing Record 8 of Set 10 | ust-ishim
# Processing Record 9 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 10 | hirara
# Processing Record 11 of Set 10 | liepaja
# Processing Record 12 of Set 10 | eyl
# Processing Record 13 of Set 10 | ginda
# Processing Record 14 of Set 10 | hamilton
# Processing Record 15 of Set 10 | tabuk
# Processing Record 16 of Set 10 | zaria
# Processing Record 17 of Set 10 | novyye burasy
# Processing Record 18 of Set 10 | arman
# Processing Record 19 of Set 10 | coihaique
# Processing Record 20 of Set 10 | sungai udang
# Processing Record 21 of Set 10 | fort saint james
# Processing Record 22 of Set 10 | novyy urengoy
# Processing Record 23 of Set 10 | cidreira
# Processing Record 24 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 25 of Set 10 | olinda
# Processing Record 26 of Set 10 | port augusta
# Processing Record 27 of Set 10 | buraydah
# Processing Record 28 of Set 10 | pilar
# Processing Record 29 of Set 10 | waingapu
# Processing Record 30 of Set 10 | bulgan
# Processing Record 31 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 10 | socorro
# Processing Record 33 of Set 10 | faya
# Processing Record 34 of Set 10 | avera
# Processing Record 35 of Set 10 | fortuna
# Processing Record 36 of Set 10 | mayo
# Processing Record 37 of Set 10 | apaxtla
# City not found. Skipping...
# Processing Record 38 of Set 10 | ulaangom
# Processing Record 39 of Set 10 | sibolga
# Processing Record 40 of Set 10 | lamu
# Processing Record 41 of Set 10 | lekoni
# Processing Record 42 of Set 10 | chom bung
# City not found. Skipping...
# Processing Record 43 of Set 10 | kailua
# Processing Record 44 of Set 10 | springbok
# Processing Record 45 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 10 | esqueda
# Processing Record 47 of Set 10 | villa maria
# Processing Record 48 of Set 10 | santa luzia
# Processing Record 49 of Set 10 | mikuni
# Processing Record 50 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 1 of Set 11 | sao miguel do araguaia
# Processing Record 2 of Set 11 | ahuimanu
# Processing Record 3 of Set 11 | aleksandrov gay
# Processing Record 4 of Set 11 | tobetsu
# Processing Record 5 of Set 11 | korla
# Processing Record 6 of Set 11 | sao filipe
# Processing Record 7 of Set 11 | ketchikan
# Processing Record 8 of Set 11 | wawa
# Processing Record 9 of Set 11 | thai binh
# Processing Record 10 of Set 11 | tessalit
# Processing Record 11 of Set 11 | murray bridge
# Processing Record 12 of Set 11 | inirida
# Processing Record 13 of Set 11 | senanga
# Processing Record 14 of Set 11 | aksha
# Processing Record 15 of Set 11 | san jose
# Processing Record 16 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 17 of Set 11 | dosso
# Processing Record 18 of Set 11 | saldanha
# Processing Record 19 of Set 11 | saint-francois
# Processing Record 20 of Set 11 | zlotow
# Processing Record 21 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 22 of Set 11 | port-gentil
# Processing Record 23 of Set 11 | shakiso
# Processing Record 24 of Set 11 | vanavara
# Processing Record 25 of Set 11 | necochea
# Processing Record 26 of Set 11 | terme
# Processing Record 27 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 28 of Set 11 | el tocuyo
# Processing Record 29 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 30 of Set 11 | siuna
# Processing Record 31 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 32 of Set 11 | naukot
# Processing Record 33 of Set 11 | pangdan
# Processing Record 34 of Set 11 | san roque
# Processing Record 35 of Set 11 | srandakan
# Processing Record 36 of Set 11 | sembe
# Processing Record 37 of Set 11 | groningen
# Processing Record 38 of Set 11 | la ronge
# Processing Record 39 of Set 11 | atar
# Processing Record 40 of Set 11 | gemena
# Processing Record 41 of Set 11 | nemuro
# Processing Record 42 of Set 11 | alice springs
# Processing Record 43 of Set 11 | asekeyevo
# Processing Record 44 of Set 11 | minador do negrao
# Processing Record 45 of Set 11 | miri
# Processing Record 46 of Set 11 | lokosovo
# Processing Record 47 of Set 11 | gat
# Processing Record 48 of Set 11 | tucuman
# Processing Record 49 of Set 11 | asfi
# Processing Record 50 of Set 11 | kutum
# Processing Record 1 of Set 12 | aguimes
# Processing Record 2 of Set 12 | ternate
# Processing Record 3 of Set 12 | dangriga
# Processing Record 4 of Set 12 | manicore
# Processing Record 5 of Set 12 | saint stephen
# Processing Record 6 of Set 12 | suining
# Processing Record 7 of Set 12 | gilbues
# Processing Record 8 of Set 12 | ambon
# Processing Record 9 of Set 12 | mahibadhoo
# Processing Record 10 of Set 12 | khorixas
# Processing Record 11 of Set 12 | mankato
# Processing Record 12 of Set 12 | rocha
# Processing Record 13 of Set 12 | flin flon
# Processing Record 14 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 15 of Set 12 | oudtshoorn
# Processing Record 16 of Set 12 | choix
# Processing Record 17 of Set 12 | grand gaube
# Processing Record 18 of Set 12 | kholmogory
# Processing Record 19 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 12 | bac can
# City not found. Skipping...
# Processing Record 21 of Set 12 | blagoyevo
# Processing Record 22 of Set 12 | shuyskoye
# Processing Record 23 of Set 12 | nalut
# Processing Record 24 of Set 12 | srednekolymsk
# Processing Record 25 of Set 12 | margate
# Processing Record 26 of Set 12 | boyolangu
# Processing Record 27 of Set 12 | fuerte olimpo
# Processing Record 28 of Set 12 | otuzco
# Processing Record 29 of Set 12 | caravelas
# Processing Record 30 of Set 12 | farmington
# Processing Record 31 of Set 12 | northam
# Processing Record 32 of Set 12 | roma
# Processing Record 33 of Set 12 | independence
# Processing Record 34 of Set 12 | palmer
# Processing Record 35 of Set 12 | poum
# Processing Record 36 of Set 12 | ulladulla
# Processing Record 37 of Set 12 | calvinia
# Processing Record 38 of Set 12 | cabedelo
# Processing Record 39 of Set 12 | salalah
# Processing Record 40 of Set 12 | lincoln
# Processing Record 41 of Set 12 | maskinonge
# Processing Record 42 of Set 12 | bela
# Processing Record 43 of Set 12 | nizhniy kuranakh
# Processing Record 44 of Set 12 | nacimiento
# Processing Record 45 of Set 12 | yambio
# Processing Record 46 of Set 12 | ferkessedougou
# Processing Record 47 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 12 | maceio
# Processing Record 49 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 12 | urumqi
# Processing Record 1 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 13 | ancud
# Processing Record 3 of Set 13 | jumla
# Processing Record 4 of Set 13 | tuy hoa
# Processing Record 5 of Set 13 | praia da vitoria
# Processing Record 6 of Set 13 | nelson bay
# Processing Record 7 of Set 13 | umm lajj
# Processing Record 8 of Set 13 | danjiangkou
# Processing Record 9 of Set 13 | sena madureira
# Processing Record 10 of Set 13 | tual
# Processing Record 11 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 12 of Set 13 | westport
# Processing Record 13 of Set 13 | iguape
# Processing Record 14 of Set 13 | barcelos
# Processing Record 15 of Set 13 | jacareacanga
# Processing Record 16 of Set 13 | celestun
# Processing Record 17 of Set 13 | havre-saint-pierre
# Processing Record 18 of Set 13 | asuncion
# Processing Record 19 of Set 13 | sokolo
# Processing Record 20 of Set 13 | sambava
# Processing Record 21 of Set 13 | kiunga
# Processing Record 22 of Set 13 | troitskoye
# Processing Record 23 of Set 13 | nosy varika
# Processing Record 24 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 13 | mareeba
# Processing Record 26 of Set 13 | rehoboth
# Processing Record 27 of Set 13 | sinnai
# Processing Record 28 of Set 13 | khandyga
# Processing Record 29 of Set 13 | novobirilyussy
# Processing Record 30 of Set 13 | vrsac
# Processing Record 31 of Set 13 | bar harbor
# Processing Record 32 of Set 13 | clarksburg
# Processing Record 33 of Set 13 | alofi
# Processing Record 34 of Set 13 | kusu
# Processing Record 35 of Set 13 | quilmana
# Processing Record 36 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 13 | slave lake
# Processing Record 38 of Set 13 | ternovka
# Processing Record 39 of Set 13 | sao joao da barra
# Processing Record 40 of Set 13 | mount isa
# Processing Record 41 of Set 13 | borba
# Processing Record 42 of Set 13 | kuito
# Processing Record 43 of Set 13 | souillac
# Processing Record 44 of Set 13 | nantucket
# Processing Record 45 of Set 13 | huntsville
# Processing Record 46 of Set 13 | stornoway
# Processing Record 47 of Set 13 | kyaikkami
# Processing Record 48 of Set 13 | canete
# Processing Record 49 of Set 13 | araouane
# Processing Record 50 of Set 13 | taltal
# Processing Record 1 of Set 14 | lazaro cardenas
# Processing Record 2 of Set 14 | camacha
# Processing Record 3 of Set 14 | walvis bay
# Processing Record 4 of Set 14 | turukhansk
# Processing Record 5 of Set 14 | ukiah
# Processing Record 6 of Set 14 | teontepec
# Processing Record 7 of Set 14 | hami
# Processing Record 8 of Set 14 | trairi
# Processing Record 9 of Set 14 | sawakin
# Processing Record 10 of Set 14 | kose
# Processing Record 11 of Set 14 | shiyan
# Processing Record 12 of Set 14 | nichinan
# Processing Record 13 of Set 14 | shitanjing
# Processing Record 14 of Set 14 | amsterdam
# Processing Record 15 of Set 14 | kattivakkam
# Processing Record 16 of Set 14 | bradford
# Processing Record 17 of Set 14 | pitiquito
# Processing Record 18 of Set 14 | sao felix do xingu
# Processing Record 19 of Set 14 | healdsburg
# Processing Record 20 of Set 14 | svetlogorsk
# Processing Record 21 of Set 14 | teya
# Processing Record 22 of Set 14 | mongagua
# Processing Record 23 of Set 14 | duluth
# Processing Record 24 of Set 14 | gueret
# Processing Record 25 of Set 14 | jhinjhak
# Processing Record 26 of Set 14 | riberalta
# Processing Record 27 of Set 14 | salamiyah
# Processing Record 28 of Set 14 | hongjiang
# Processing Record 29 of Set 14 | lumsden
# Processing Record 30 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 32 of Set 14 | pacifica
# Processing Record 33 of Set 14 | namibe
# Processing Record 34 of Set 14 | hornepayne
# Processing Record 35 of Set 14 | bhikangaon
# Processing Record 36 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 14 | grenville
# Processing Record 38 of Set 14 | kayes
# Processing Record 39 of Set 14 | voznesenye
# Processing Record 40 of Set 14 | kirakira
# Processing Record 41 of Set 14 | the valley
# Processing Record 42 of Set 14 | kargat
# Processing Record 43 of Set 14 | ouadda
# Processing Record 44 of Set 14 | miles city
# Processing Record 45 of Set 14 | talara
# Processing Record 46 of Set 14 | cochrane
# Processing Record 47 of Set 14 | gobabis
# Processing Record 48 of Set 14 | puerto carreno
# Processing Record 49 of Set 14 | manama
# Processing Record 50 of Set 14 | wanaka
# Processing Record 1 of Set 15 | sitrah
# Processing Record 2 of Set 15 | puerto colombia
# Processing Record 3 of Set 15 | moron
# Processing Record 4 of Set 15 | kudahuvadhoo
# Processing Record 5 of Set 15 | wajima
# Processing Record 6 of Set 15 | bongaree
# Processing Record 7 of Set 15 | mazyr
# Processing Record 8 of Set 15 | totolapa
# Processing Record 9 of Set 15 | ongandjera
# Processing Record 10 of Set 15 | senmonorom
# City not found. Skipping...
# Processing Record 11 of Set 15 | raymondville
# Processing Record 12 of Set 15 | thabazimbi
# Processing Record 13 of Set 15 | adrar
# Processing Record 14 of Set 15 | lalsk
# Processing Record 15 of Set 15 | yar-sale
# Processing Record 16 of Set 15 | prieska
# Processing Record 17 of Set 15 | port moresby
# Processing Record 18 of Set 15 | seddon
# Processing Record 19 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 20 of Set 15 | florianopolis
# Processing Record 21 of Set 15 | carutapera
# Processing Record 22 of Set 15 | majene
# Processing Record 23 of Set 15 | cabinda
# Processing Record 24 of Set 15 | shevchenkove
# Processing Record 25 of Set 15 | santa cruz de la palma
# Processing Record 26 of Set 15 | shubarshi
# Processing Record 27 of Set 15 | haines junction
# Processing Record 28 of Set 15 | axim
# Processing Record 29 of Set 15 | tonatico
# Processing Record 30 of Set 15 | juneau
# Processing Record 31 of Set 15 | gamba
# Processing Record 32 of Set 15 | swan river
# Processing Record 33 of Set 15 | damavand
# Processing Record 34 of Set 15 | fasa
# Processing Record 35 of Set 15 | shanghai
# Processing Record 36 of Set 15 | bandarbeyla
# Processing Record 37 of Set 15 | sisimiut
# Processing Record 38 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 15 | andenes
# Processing Record 40 of Set 15 | nyurba
# Processing Record 41 of Set 15 | xichang
# Processing Record 42 of Set 15 | krasnokamensk
# Processing Record 43 of Set 15 | kavaratti
# Processing Record 44 of Set 15 | pierre
# Processing Record 45 of Set 15 | tiarei
# Processing Record 46 of Set 15 | myitkyina
# Processing Record 47 of Set 15 | boppard
# Processing Record 48 of Set 15 | bilibino
# Processing Record 49 of Set 15 | sinnamary
# Processing Record 50 of Set 15 | abha
# Processing Record 1 of Set 16 | funtua
# Processing Record 2 of Set 16 | naryan-mar
# Processing Record 3 of Set 16 | manzanillo
# Processing Record 4 of Set 16 | yanchukan
# City not found. Skipping...
# Processing Record 5 of Set 16 | kimbe
# Processing Record 6 of Set 16 | utiel
# Processing Record 7 of Set 16 | safaqis
# City not found. Skipping...
# Processing Record 8 of Set 16 | itapirapua
# Processing Record 9 of Set 16 | antofagasta
# Processing Record 10 of Set 16 | kapuskasing
# Processing Record 11 of Set 16 | ekimchan
# Processing Record 12 of Set 16 | chicama
# Processing Record 13 of Set 16 | dourbali
# Processing Record 14 of Set 16 | limoeiro
# Processing Record 15 of Set 16 | calamar
# Processing Record 16 of Set 16 | barra patuca
# Processing Record 17 of Set 16 | arlit
# Processing Record 18 of Set 16 | kjollefjord
# Processing Record 19 of Set 16 | jamame
# Processing Record 20 of Set 16 | mocuba
# Processing Record 21 of Set 16 | umm durman
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Narsaq      GL  60.9167  -46.0500     37.29        99         100
# 1      Thompson      CA  55.7435  -97.8558     -3.84        77          75
# 2    Nikolskoye      RU  59.7035   30.7861     40.87        97         100
# 3    Mwinilunga      ZM -11.7358   24.4293     62.64        84         100
# 4      Avinurme      EE  58.9822   26.8642     37.04        95         100
# 5      Cherskiy      RU  68.7500  161.3000    -27.87       100         100
# 6     Jamestown      US  42.0970  -79.2353     44.19        95          90
# 7  San Fernando      PH  15.0286  120.6898     80.69        80         100
# 8       Rikitea      PF -23.1203 -134.9692     76.95        70           9
# 9     Upernavik      GL  72.7868  -56.1549     22.33        76         100
#
#    Wind Speed Current Description
# 0        7.94          light rain
# 1        2.30       broken clouds
# 2       12.91     overcast clouds
# 3        2.55     overcast clouds
# 4       13.20     overcast clouds
# 5        4.43     overcast clouds
# 6        5.99                mist
# 7        4.59     overcast clouds
# 8        9.98           clear sky
# 9        9.35     overcast clouds

# %%
#Create the outpute file (CSV)
output_data_file = "WeatherPy_Database.csv"
#Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
